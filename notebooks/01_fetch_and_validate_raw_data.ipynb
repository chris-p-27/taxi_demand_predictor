# %%
from pathlib import Path
import requests
from datetime import datetime

def download_one_file_of_raw_data(year: int, month: int, save_dir: str = "./data/raw/") -> Path:
    """
    Download a single month's data for the specified year.
    
    Parameters:
        year (int): The year of the data to download.
        month (int): The month of the data to download.
        save_dir (str): Directory to save the downloaded file.
        
    Returns:
        Path: The path to the saved file.
    """
    # URL template
    URL = f'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{year}-{month:02d}.parquet'
    response = requests.get(URL)

    # Check if the request succeeded
    if response.status_code == 200:
        # Save the file
        path = Path(save_dir) / f"yellow_tripdata_{year}-{month:02d}.parquet"
        path.parent.mkdir(parents=True, exist_ok=True)  # Create directories if needed
        with open(path, "wb") as file:
            file.write(response.content)
        print(f"Downloaded: {path}")
        return path
    else:
        print(f"File not found for {year}-{month:02d}: {URL}")
        return None

def download_full_dataset(start_year: int, start_month: int, end_year: int, end_month: int, save_dir: str = "./data/raw/"):
    """
    Download the full dataset from the specified start year/month to end year/month.
    
    Parameters:
        start_year (int): The starting year.
        start_month (int): The starting month.
        end_year (int): The ending year.
        end_month (int): The ending month.
        save_dir (str): Directory to save the downloaded files.
    """
    for year in range(start_year, end_year + 1):
        for month in range(1, 13):
            # Stop if the year and month exceed the range
            if year == end_year and month > end_month:
                break
            # Download the file
            try:
                download_one_file_of_raw_data(year, month, save_dir)
            except Exception as e:
                print(f"Error downloading {year}-{month:02d}: {e}")

# Example usage: Download all data from January 2009 to September 2024
download_full_dataset(start_year=2009, start_month=1, end_year=2024, end_month=9)
# Out:
# Downloaded: data\raw\yellow_tripdata_2009-01.parquet
# Downloaded: data\raw\yellow_tripdata_2009-02.parquet
# Downloaded: data\raw\yellow_tripdata_2009-03.parquet
# Downloaded: data\raw\yellow_tripdata_2009-04.parquet
# Downloaded: data\raw\yellow_tripdata_2009-05.parquet
# Downloaded: data\raw\yellow_tripdata_2009-06.parquet
# Downloaded: data\raw\yellow_tripdata_2009-07.parquet
# Downloaded: data\raw\yellow_tripdata_2009-08.parquet
# Downloaded: data\raw\yellow_tripdata_2009-09.parquet
# Downloaded: data\raw\yellow_tripdata_2009-10.parquet
# Downloaded: data\raw\yellow_tripdata_2009-11.parquet
# Downloaded: data\raw\yellow_tripdata_2009-12.parquet
# Downloaded: data\raw\yellow_tripdata_2010-01.parquet
# Downloaded: data\raw\yellow_tripdata_2010-02.parquet
# Downloaded: data\raw\yellow_tripdata_2010-03.parquet
# Downloaded: data\raw\yellow_tripdata_2010-04.parquet
# Downloaded: data\raw\yellow_tripdata_2010-05.parquet
# Downloaded: data\raw\yellow_tripdata_2010-06.parquet
# Downloaded: data\raw\yellow_tripdata_2010-07.parquet
# Downloaded: data\raw\yellow_tripdata_2010-08.parquet
# Downloaded: data\raw\yellow_tripdata_2010-09.parquet
# Downloaded: data\raw\yellow_tripdata_2010-10.parquet
# Downloaded: data\raw\yellow_tripdata_2010-11.parquet
# Downloaded: data\raw\yellow_tripdata_2010-12.parquet
# Downloaded: data\raw\yellow_tripdata_2011-01.parquet
# Downloaded: data\raw\yellow_tripdata_2011-02.parquet
# Downloaded: data\raw\yellow_tripdata_2011-03.parquet
# Downloaded: data\raw\yellow_tripdata_2011-04.parquet
# Downloaded: data\raw\yellow_tripdata_2011-05.parquet
# Downloaded: data\raw\yellow_tripdata_2011-06.parquet
# Downloaded: data\raw\yellow_tripdata_2011-07.parquet
# Downloaded: data\raw\yellow_tripdata_2011-08.parquet
# Downloaded: data\raw\yellow_tripdata_2011-09.parquet
# Downloaded: data\raw\yellow_tripdata_2011-10.parquet
# Downloaded: data\raw\yellow_tripdata_2011-11.parquet
# Downloaded: data\raw\yellow_tripdata_2011-12.parquet
# Downloaded: data\raw\yellow_tripdata_2012-01.parquet
# Downloaded: data\raw\yellow_tripdata_2012-02.parquet
# Downloaded: data\raw\yellow_tripdata_2012-03.parquet
# Downloaded: data\raw\yellow_tripdata_2012-04.parquet
# Downloaded: data\raw\yellow_tripdata_2012-05.parquet
# Downloaded: data\raw\yellow_tripdata_2012-06.parquet
# Downloaded: data\raw\yellow_tripdata_2012-07.parquet
# Downloaded: data\raw\yellow_tripdata_2012-08.parquet
# Downloaded: data\raw\yellow_tripdata_2012-09.parquet
# Downloaded: data\raw\yellow_tripdata_2012-10.parquet
# Downloaded: data\raw\yellow_tripdata_2012-11.parquet
# Downloaded: data\raw\yellow_tripdata_2012-12.parquet
# Downloaded: data\raw\yellow_tripdata_2013-01.parquet
# Downloaded: data\raw\yellow_tripdata_2013-02.parquet
# Downloaded: data\raw\yellow_tripdata_2013-03.parquet
# Downloaded: data\raw\yellow_tripdata_2013-04.parquet
# Downloaded: data\raw\yellow_tripdata_2013-05.parquet
# Downloaded: data\raw\yellow_tripdata_2013-06.parquet
# Downloaded: data\raw\yellow_tripdata_2013-07.parquet
# Downloaded: data\raw\yellow_tripdata_2013-08.parquet
# Downloaded: data\raw\yellow_tripdata_2013-09.parquet
# Downloaded: data\raw\yellow_tripdata_2013-10.parquet
# Downloaded: data\raw\yellow_tripdata_2013-11.parquet
# Downloaded: data\raw\yellow_tripdata_2013-12.parquet
# Downloaded: data\raw\yellow_tripdata_2014-01.parquet
# Downloaded: data\raw\yellow_tripdata_2014-02.parquet
# Downloaded: data\raw\yellow_tripdata_2014-03.parquet
# Downloaded: data\raw\yellow_tripdata_2014-04.parquet
# Downloaded: data\raw\yellow_tripdata_2014-05.parquet
# Downloaded: data\raw\yellow_tripdata_2014-06.parquet
# Downloaded: data\raw\yellow_tripdata_2014-07.parquet
# Downloaded: data\raw\yellow_tripdata_2014-08.parquet
# Downloaded: data\raw\yellow_tripdata_2014-09.parquet
# Downloaded: data\raw\yellow_tripdata_2014-10.parquet
# Downloaded: data\raw\yellow_tripdata_2014-11.parquet
# Downloaded: data\raw\yellow_tripdata_2014-12.parquet
# Downloaded: data\raw\yellow_tripdata_2015-01.parquet
# Downloaded: data\raw\yellow_tripdata_2015-02.parquet
# Downloaded: data\raw\yellow_tripdata_2015-03.parquet
# Downloaded: data\raw\yellow_tripdata_2015-04.parquet
# Downloaded: data\raw\yellow_tripdata_2015-05.parquet
# Downloaded: data\raw\yellow_tripdata_2015-06.parquet
# Downloaded: data\raw\yellow_tripdata_2015-07.parquet
# Downloaded: data\raw\yellow_tripdata_2015-08.parquet
# Downloaded: data\raw\yellow_tripdata_2015-09.parquet
# Downloaded: data\raw\yellow_tripdata_2015-10.parquet
# Downloaded: data\raw\yellow_tripdata_2015-11.parquet
# Downloaded: data\raw\yellow_tripdata_2015-12.parquet
# Downloaded: data\raw\yellow_tripdata_2016-01.parquet
# Downloaded: data\raw\yellow_tripdata_2016-02.parquet
# Downloaded: data\raw\yellow_tripdata_2016-03.parquet
# Downloaded: data\raw\yellow_tripdata_2016-04.parquet
# Downloaded: data\raw\yellow_tripdata_2016-05.parquet
# Downloaded: data\raw\yellow_tripdata_2016-06.parquet
# Downloaded: data\raw\yellow_tripdata_2016-07.parquet
# Downloaded: data\raw\yellow_tripdata_2016-08.parquet
# Downloaded: data\raw\yellow_tripdata_2016-09.parquet
# Downloaded: data\raw\yellow_tripdata_2016-10.parquet
# Downloaded: data\raw\yellow_tripdata_2016-11.parquet
# Downloaded: data\raw\yellow_tripdata_2016-12.parquet
# Downloaded: data\raw\yellow_tripdata_2017-01.parquet
# Downloaded: data\raw\yellow_tripdata_2017-02.parquet
# Downloaded: data\raw\yellow_tripdata_2017-03.parquet
# Downloaded: data\raw\yellow_tripdata_2017-04.parquet
# Downloaded: data\raw\yellow_tripdata_2017-05.parquet
# Downloaded: data\raw\yellow_tripdata_2017-06.parquet
# Downloaded: data\raw\yellow_tripdata_2017-07.parquet
# Downloaded: data\raw\yellow_tripdata_2017-08.parquet
# Downloaded: data\raw\yellow_tripdata_2017-09.parquet
# Downloaded: data\raw\yellow_tripdata_2017-10.parquet
# Downloaded: data\raw\yellow_tripdata_2017-11.parquet
# Downloaded: data\raw\yellow_tripdata_2017-12.parquet
# Downloaded: data\raw\yellow_tripdata_2018-01.parquet
# Downloaded: data\raw\yellow_tripdata_2018-02.parquet
# Downloaded: data\raw\yellow_tripdata_2018-03.parquet
# Downloaded: data\raw\yellow_tripdata_2018-04.parquet
# Downloaded: data\raw\yellow_tripdata_2018-05.parquet
# Downloaded: data\raw\yellow_tripdata_2018-06.parquet
# Downloaded: data\raw\yellow_tripdata_2018-07.parquet
# Downloaded: data\raw\yellow_tripdata_2018-08.parquet
# Downloaded: data\raw\yellow_tripdata_2018-09.parquet
# Downloaded: data\raw\yellow_tripdata_2018-10.parquet
# Downloaded: data\raw\yellow_tripdata_2018-11.parquet
# Downloaded: data\raw\yellow_tripdata_2018-12.parquet
# Downloaded: data\raw\yellow_tripdata_2019-01.parquet
# Downloaded: data\raw\yellow_tripdata_2019-02.parquet
# Downloaded: data\raw\yellow_tripdata_2019-03.parquet
# Downloaded: data\raw\yellow_tripdata_2019-04.parquet
# Downloaded: data\raw\yellow_tripdata_2019-05.parquet
# Downloaded: data\raw\yellow_tripdata_2019-06.parquet
# Downloaded: data\raw\yellow_tripdata_2019-07.parquet
# Downloaded: data\raw\yellow_tripdata_2019-08.parquet
# Downloaded: data\raw\yellow_tripdata_2019-09.parquet
# Downloaded: data\raw\yellow_tripdata_2019-10.parquet
# Downloaded: data\raw\yellow_tripdata_2019-11.parquet
# Downloaded: data\raw\yellow_tripdata_2019-12.parquet
# Downloaded: data\raw\yellow_tripdata_2020-01.parquet
# Downloaded: data\raw\yellow_tripdata_2020-02.parquet
# Downloaded: data\raw\yellow_tripdata_2020-03.parquet
# Downloaded: data\raw\yellow_tripdata_2020-04.parquet
# Downloaded: data\raw\yellow_tripdata_2020-05.parquet
# Downloaded: data\raw\yellow_tripdata_2020-06.parquet
# Downloaded: data\raw\yellow_tripdata_2020-07.parquet
# Downloaded: data\raw\yellow_tripdata_2020-08.parquet
# Downloaded: data\raw\yellow_tripdata_2020-09.parquet
# Downloaded: data\raw\yellow_tripdata_2020-10.parquet
# Downloaded: data\raw\yellow_tripdata_2020-11.parquet
# Downloaded: data\raw\yellow_tripdata_2020-12.parquet
# Downloaded: data\raw\yellow_tripdata_2021-01.parquet
# Downloaded: data\raw\yellow_tripdata_2021-02.parquet
# Downloaded: data\raw\yellow_tripdata_2021-03.parquet
# Downloaded: data\raw\yellow_tripdata_2021-04.parquet
# Downloaded: data\raw\yellow_tripdata_2021-05.parquet
# Downloaded: data\raw\yellow_tripdata_2021-06.parquet
# Downloaded: data\raw\yellow_tripdata_2021-07.parquet
# Downloaded: data\raw\yellow_tripdata_2021-08.parquet
# Downloaded: data\raw\yellow_tripdata_2021-09.parquet
# Downloaded: data\raw\yellow_tripdata_2021-10.parquet
# Downloaded: data\raw\yellow_tripdata_2021-11.parquet
# Downloaded: data\raw\yellow_tripdata_2021-12.parquet
# Downloaded: data\raw\yellow_tripdata_2022-01.parquet
# Downloaded: data\raw\yellow_tripdata_2022-02.parquet
# Downloaded: data\raw\yellow_tripdata_2022-03.parquet
# Downloaded: data\raw\yellow_tripdata_2022-04.parquet
# Downloaded: data\raw\yellow_tripdata_2022-05.parquet
# Downloaded: data\raw\yellow_tripdata_2022-06.parquet
# Downloaded: data\raw\yellow_tripdata_2022-07.parquet
# Downloaded: data\raw\yellow_tripdata_2022-08.parquet
# Downloaded: data\raw\yellow_tripdata_2022-09.parquet
# Downloaded: data\raw\yellow_tripdata_2022-10.parquet
# Downloaded: data\raw\yellow_tripdata_2022-11.parquet
# Downloaded: data\raw\yellow_tripdata_2022-12.parquet
# Downloaded: data\raw\yellow_tripdata_2023-01.parquet
# Downloaded: data\raw\yellow_tripdata_2023-02.parquet
# Downloaded: data\raw\yellow_tripdata_2023-03.parquet
# Downloaded: data\raw\yellow_tripdata_2023-04.parquet
# Downloaded: data\raw\yellow_tripdata_2023-05.parquet
# Downloaded: data\raw\yellow_tripdata_2023-06.parquet
# Downloaded: data\raw\yellow_tripdata_2023-07.parquet
# Downloaded: data\raw\yellow_tripdata_2023-08.parquet
# Downloaded: data\raw\yellow_tripdata_2023-09.parquet
# Downloaded: data\raw\yellow_tripdata_2023-10.parquet
# Downloaded: data\raw\yellow_tripdata_2023-11.parquet
# Downloaded: data\raw\yellow_tripdata_2023-12.parquet
# Downloaded: data\raw\yellow_tripdata_2024-01.parquet
# Downloaded: data\raw\yellow_tripdata_2024-02.parquet
# Downloaded: data\raw\yellow_tripdata_2024-03.parquet
# Downloaded: data\raw\yellow_tripdata_2024-04.parquet
# Downloaded: data\raw\yellow_tripdata_2024-05.parquet
# Downloaded: data\raw\yellow_tripdata_2024-06.parquet
# Downloaded: data\raw\yellow_tripdata_2024-07.parquet
# Downloaded: data\raw\yellow_tripdata_2024-08.parquet
# Downloaded: data\raw\yellow_tripdata_2024-09.parquet

# %%
download_one_file_of_raw_data(year=2022, month=1)
# Out:
# Downloaded: data\raw\rides_2022-01.parquet
# WindowsPath('data/raw/rides_2022-01.parquet')

# %%
import pandas as pd

file_path = "./data/raw/rides_2022-01.parquet"  # Relative to the notebooks folder
rides = pd.read_parquet(file_path)
print(rides.head(20))
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1          1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2          2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3          2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4          2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# 5          1  2022-01-01 00:40:15   2022-01-01 01:09:48              1.0
# 6          2  2022-01-01 00:20:50   2022-01-01 00:34:58              1.0
# 7          2  2022-01-01 00:13:04   2022-01-01 00:22:45              1.0
# 8          2  2022-01-01 00:30:02   2022-01-01 00:44:49              1.0
# 9          2  2022-01-01 00:48:52   2022-01-01 00:53:28              1.0
# 10         2  2022-01-01 00:55:03   2022-01-01 01:04:25              1.0
# 11         2  2022-01-01 00:31:06   2022-01-01 00:34:14              3.0
# 12         2  2022-01-01 00:41:07   2022-01-01 00:44:46              3.0
# 13         2  2022-01-01 00:56:34   2022-01-01 01:12:04              2.0
# 14         2  2022-01-01 00:39:46   2022-01-01 00:47:36              4.0
# 15         2  2022-01-01 00:58:06   2022-01-01 01:05:45              1.0
# 16         1  2022-01-01 00:33:52   2022-01-01 00:47:28              3.0
# 17         1  2022-01-01 00:53:54   2022-01-01 01:05:20              2.0
# 18         1  2022-01-01 00:00:44   2022-01-01 00:05:29              1.0
# 19         1  2022-01-01 00:35:50   2022-01-01 00:48:33              2.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            3.80         1.0                  N           142           236
# 1            2.10         1.0                  N           236            42
# 2            0.97         1.0                  N           166           166
# 3            1.09         1.0                  N           114            68
# 4            4.30         1.0                  N            68           163
# 5           10.30         1.0                  N           138           161
# 6            5.07         1.0                  N           233            87
# 7            2.02         1.0                  N           238           152
# 8            2.71         1.0                  N           166           236
# 9            0.78         1.0                  N           236           141
# 10           1.91         1.0                  N           141           229
# 11           0.82         1.0                  N           114            90
# 12           0.73         1.0                  N           234           113
# 13           2.16         1.0                  N           246            79
# 14           1.43         1.0                  N            43           140
# 15           1.58         1.0                  N           239           151
# 16           4.20         1.0                  N           148           141
# 17           2.20         1.0                  N           237           107
# 18           0.20         1.0                  N             7             7
# 19           3.90         1.0                  N           107           263
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              1         14.5    3.0      0.5        3.65          0.00
# 1              1          8.0    0.5      0.5        4.00          0.00
# 2              1          7.5    0.5      0.5        1.76          0.00
# 3              2          8.0    0.5      0.5        0.00          0.00
# 4              1         23.5    0.5      0.5        3.00          0.00
# 5              1         33.0    3.0      0.5       13.00          6.55
# 6              1         17.0    0.5      0.5        5.20          0.00
# 7              2          9.0    0.5      0.5        0.00          0.00
# 8              1         12.0    0.5      0.5        2.25          0.00
# 9              2          5.0    0.5      0.5        0.00          0.00
# 10             2          8.5    0.5      0.5        0.00          0.00
# 11             2          4.5    0.5      0.5        0.00          0.00
# 12             2          4.5    0.5      0.5        0.00          0.00
# 13             1         11.5    0.5      0.5        3.06          0.00
# 14             1          7.5    0.5      0.5        2.26          0.00
# 15             2          8.0    0.5      0.5        0.00          0.00
# 16             1         14.0    2.5      0.5        3.45          0.00
# 17             1          9.5    2.5      0.5        2.55          0.00
# 18             2          5.0    0.5      0.5        0.00          0.00
# 19             1         13.0    3.0      0.5        3.35          0.00
#
#     improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                     0.3         21.95                   2.5          0.0
# 1                     0.3         13.30                   0.0          0.0
# 2                     0.3         10.56                   0.0          0.0
# 3                     0.3         11.80                   2.5          0.0
# 4                     0.3         30.30                   2.5          0.0
# 5                     0.3         56.35                   2.5          0.0
# 6                     0.3         26.00                   2.5          0.0
# 7                     0.3         12.80                   2.5          0.0
# 8                     0.3         18.05                   2.5          0.0
# 9                     0.3          8.80                   2.5          0.0
# 10                    0.3         12.30                   2.5          0.0
# 11                    0.3          8.30                   2.5          0.0
# 12                    0.3          8.30                   2.5          0.0
# 13                    0.3         18.36                   2.5          0.0
# 14                    0.3         13.56                   2.5          0.0
# 15                    0.3         11.80                   2.5          0.0
# 16                    0.3         20.75                   2.5          0.0
# 17                    0.3         15.35                   2.5          0.0
# 18                    0.3          6.30                   0.0          0.0
# 19                    0.3         20.15                   2.5          0.0
